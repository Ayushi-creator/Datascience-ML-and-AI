# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushi-creator/Datascience-ML-and-AI/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BeautifulSoup

# %%
from bs4 import BeautifulSoup
import requests

# %%
flipkart=requests.get("https://www.flipkart.com/search?q=iphone+14+pro")

# %%
print(flipkart.content)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57
# ...

# %%
type(flipkart.content)
# Out:
# bytes

# %%
flipkart.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57"
# ...

# %%
type(flipkart.text)
# Out:
# str

# %%
soup=BeautifulSoup(flipkart.text,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# ...

# %%
soup.title
# Out:
# <title>Iphone 14 Pro- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>

# %%
soup.title.text
# Out:
# 'Iphone 14 Pro- Buy Products Online at Best Price in India - All Categories | Flipkart.com'

# %%
soup.p
# Out:
# <p class="_2-N8zT">Just wow!</p>

# %%
soup.div
# Out:
# <div id="container"><div><div class="_1kfTjk"><div class="_1rH5Jn"><div class="_1TmfNK"></div><div class="_2Xfa2_"><div class="_3_C9Hx"><div class="_3qX0zy"><a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a><a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a></div></div><div class="_1cmsER"><form action="/search" class="_2M8cLY header-form-search" method="GET"><div class="col-12-12 _2oO9oE"><div class="_3OO5Xc"><input autocomplete="off" class="_3704LK" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value="iphone 14 pro"/></div><button class="L0Z3Pu" type="submit"><svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg">
# ...

# %%
soup.div.text
# Out:
# 'Explore PlusLoginBecome a Seller More CartFiltersCATEGORIESMobiles & AccessoriesMobilesPrice......Min₹10000₹15000₹20000₹30000to₹10000₹15000₹20000₹30000₹30000+BrandAPPLE?Customer Ratings4★ & above3★ & aboveGST Invoice AvailableRAM1GB and BelowInternal StorageBattery CapacityScreen SizePrimary CameraSecondary CameraProcessor BrandSpecialityResolution TypeOperating SystemNetwork TypeSim TypeOffersSpecial PriceNo Cost EMIFeaturesTypeNumber of CoresAvailabilityDiscount50% or more40% or more30% or more20% or more10% or moreClock SpeedNeed help?Help me decideHomeMobiles & AccessoriesMobilesShowing 1 – 24 of 62 results for "iphone 14 pro"Sort ByRelevancePopularityPrice -- Low to HighPrice -- High to LowNewest FirstComing SoonAdd to CompareAPPLE iPhone 14 Pro (Silver, 1 TB)4.8125 Ratings\xa0&\xa04 Reviews1 TB ROM15.49 cm (6.1 inch) Super Retina XDR Display48MP + 12MP + 12MP + 12MP | 12MP Front CameraA16 Bionic Chip, 6 Core Processor Processor1 Year Warranty for Phone and 6 Months Warranty fo
# ...

# %%
mobile=soup.find("div",class_="_1AtVbE")

# %%
mobile

# %%
print(mobile.prettify)
# Out:
# <bound method Tag.prettify of <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone+14+pro&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf 
# ...

# %%
len(mobile)
# Out:
# 1

# %%
mobiles=soup.find_all("div",attrs={"class":"_13oc-S"})

# %%
mobiles

# %%
len(mobiles)
# Out:
# 24

# %%
mobile = mobiles[0]
name = mobile.find("div", attrs = {"class": "_4rR01T"})

# %%
name
# Out:
# <div class="_4rR01T">APPLE iPhone 14 Pro (Silver, 1 TB)</div>

# %%
name.text
# Out:
# 'APPLE iPhone 14 Pro (Silver, 1 TB)'

# %%
price=mobile.find("div", attrs = {"class": "_30jeq3 _1_WHN1"})

# %%
price
# Out:
# <div class="_30jeq3 _1_WHN1">₹1,79,900</div>

# %%
price.text
# Out:
# '₹1,79,900'

# %%
rom=mobile.find("li", attrs = {"class": "rgWa7D"})

# %%
rom.text
# Out:
# '1 TB ROM'

# %%
properties=mobile.find_all("li")

# %%
properties
# Out:
# [<li class="rgWa7D">1 TB ROM</li>,
#  <li class="rgWa7D">15.49 cm (6.1 inch) Super Retina XDR Display</li>,
#  <li class="rgWa7D">48MP + 12MP + 12MP + 12MP | 12MP Front Camera</li>,
#  <li class="rgWa7D">A16 Bionic Chip, 6 Core Processor Processor</li>,
#  <li class="rgWa7D">1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories</li>]

# %%
len(properties)
# Out:
# 5

# %%
rom=properties[0]

# %%
rom
# Out:
# <li class="rgWa7D">1 TB ROM</li>

# %%
rom.text
# Out:
# '1 TB ROM'

# %%
rom.text.split(" |")
# Out:
# ['1 TB ROM']

# %%
ram.text.split(" | ")[0]

# %%
names = []
prices = []
rams = []
for mobile in mobiles:
  name = mobile.find("div", attrs = {"class": "_4rR01T"}).text
  price = mobile.find("div", class_= "_30jeq3 _1_WHN1").text
  ram = mobile.find_all("li")[0].text.split(" | ")[0]

  names.append(name)
  prices.append(price)
  rams.append(ram)

# %%
names

# %%
dist = {"Model": names, "Price": price, "RAM": ram}

# %%
import pandas as pd
df = pd.DataFrame(dist)

# %%
df

# %% [markdown]
# Extract Url

# %%
mobile.a
# Out:
# <a class="_1fQZEK" href="/apple-iphone-12-pro-graphite-128-gb/p/itm03e5f2595d843?pid=MOBFWBYZBZ7Y56WD&amp;lid=LSTMOBFWBYZBZ7Y56WDFWEMSD&amp;marketplace=FLIPKART&amp;q=iphone+14+pro&amp;store=tyy%2F4io&amp;srno=s_1_24&amp;otracker=search&amp;fm=organic&amp;iid=e60821b3-2b66-4049-9beb-4d442ae2b54e.MOBFWBYZBZ7Y56WD.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=dwnnc0tbqo0000001664728947419&amp;qH=73a41d19c3188cc2" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 12 Pro (Graphite, 128 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kg8avm80/mobile/u/q/d/apple-iphone-12-pro-dummyapplefsn-original-imafwgbrbzjgug4j.jpeg?q=70"/></div></div><div class="_3G6awp"><span class="_192laR">Currently unavailable</span></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkb
# ...

# %%
mobile.a.text
# Out:
# 'Currently unavailableAdd to CompareAPPLE iPhone 12 Pro (Graphite, 128 GB)4.51,135 Ratings\xa0&\xa081 Reviews128 GB ROM15.49 cm (6.1 inch) Super Retina XDR Display12MP + 12MP + 12MP | 12MP Front CameraA14 Bionic Chip with Next Generation Neural Engine ProcessorCeramic Shield | Industry-leading IP68 Water ResistanceAll Screen OLED DisplayLiDAR Scanner for Improved AR Experiences, Night Mode PortraitsBrand Warranty for 1 Year₹1,09,900Free deliveryUpto ₹16,900 Off on ExchangeBank Offer'

# %%
url = mobile.a["href"]
url
# Out:
# '/apple-iphone-12-pro-graphite-128-gb/p/itm03e5f2595d843?pid=MOBFWBYZBZ7Y56WD&lid=LSTMOBFWBYZBZ7Y56WDFWEMSD&marketplace=FLIPKART&q=iphone+14+pro&store=tyy%2F4io&srno=s_1_24&otracker=search&fm=organic&iid=e60821b3-2b66-4049-9beb-4d442ae2b54e.MOBFWBYZBZ7Y56WD.SEARCH&ppt=None&ppn=None&ssid=dwnnc0tbqo0000001664728947419&qH=73a41d19c3188cc2'

# %%
url = url.split("?")[0]

# %%
url
# Out:
# '/apple-iphone-12-pro-graphite-128-gb/p/itm03e5f2595d843'

# %%
url = "https://www.flipkart.com" + url

# %%
url
# Out:
# 'https://www.flipkart.com/apple-iphone-12-pro-graphite-128-gb/p/itm03e5f2595d843'

# %% [markdown]
# Extract GSOC Organizations Data

# %%
page = requests.get("https://summerofcode.withgoogle.com/archive/2021/organizations")
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text, "html.parser")
soup.title
# Out:
# <title>Google Summer of Code</title>

# %% [markdown]
# Automation

# %%
# !pip install selenium

# %%
# !apt install chromium-chromedriver
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 20 not upgraded.
# Need to get 91.7 MB of archives.
# After this operation, 309 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 105.0.5195.102-0ubuntu0.18.04.1 [1,156 kB]
# ...

# %%
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# Out:
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file

# %%
# !apt-get update
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease [1,581 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [913 kB]
# ...

# %%
from selenium import webdriver
import sys

sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

chrome_options = webdriver.ChromeOptions()

chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')

driver = webdriver.Chrome('chromedriver',chrome_options=chrome_options)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: use options instead of chrome_options
#   # This is added back by InteractiveShellApp.init_path()

# %%
import time
driver.get("https://summerofcode.withgoogle.com/archive/2021/organizations")
time.sleep(2)
page = driver.page_source

# %%
page
soup = BeautifulSoup(page, "html.parser")
soup.title
# Out:
# <title>Archive Organizations | Google Summer of Code</title>

# %%
orgs = soup.find_all("div", class_="card")
len(orgs)
# Out:
# 50

# %%
org = orgs[0]
org_name = org.find("div", class_='name')
org_name.text
# Out:
# ' 52°North GmbH '

# %%
url = "https://summerofcode.withgoogle.com/" + org.a["href"]
url
# Out:
# 'https://summerofcode.withgoogle.com//archive/2021/organizations/5129526253715456'

# %%
driver.get(url)
time.sleep(2)
page = driver.page_source
org_soup = BeautifulSoup(page, "html.parser")

# %%
tech = org_soup.find("div", class_="tech__content")

# %%
tech.text.split(", ")
# Out:
# ['python', 'javascript', 'java', 'web services', 'ogc standards']

# %% [markdown]
# Code to click on next button - LOCAL SYSTEM

# %%
from selenium import webdriver

# %%
browser = webdriver.Chrome('chromedriver')

# %%
url = "https://summerofcode.withgoogle.com/archive/2021/organizations"
browser.get(url)

# %%
from selenium.webdriver.common.by import By

button = browser.find_element(By.CSS_SELECTOR , 'body > app-root > app-layout > mat-sidenav-container > mat-sidenav-content > div > div > main > app-organizat

# %%
button.click()

# %% [markdown]
# LOGIN TO PEPCODING

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# %%
url = "https://www.pepcoding.com/login"
id = "purnachandramansingh135@gmai.com"
passwd = "purna@123"

# %%
option = webdriver.ChromeOptions()
option.add_argument("--start-maximized")
browser = webdriver.Chrome(executable_path="chromedriver.exe", options=option)

# %%
browser.get(url)
time.sleep(1)

# %%
username = browser.find_element(By.NAME, 'email')
username.send_keys(id)

# %%
username = browser.find_element(By.NAME, 'password')
username.send_keys(passwd)

# %%
login = browser.find_element(By.XPATH, '//button')
login.click()

# %%
browser.quit()

# %% [markdown]
# Read Table using Pandas

# %%
table = pd.read_html("https://sports.yahoo.com/nba/stats/team/?selectedTable=0&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAABAYuBC_")

# %%
len(table)

# %%
table
